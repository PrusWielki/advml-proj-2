# %%
DIRECTORIES = [
    "./Results/Limited",
    "./Results/Limited/MLP",
    "./Results/Limited/XGBoost",
]

# %%
OLD_COLUMNS = [
    "score",
    "numberOfTruePositives",
    "accuracy",
    "precision",
    "numberOfFeatures",
    "model",
    "model_parameters",
    "feature_selector",
    "selector_parameters",
]

NEW_COLUMNS = [
    "score",
    "numberOfTruePositives",
    "accuracy",
    "precision",
    "numberOfFeatures",
    "model",
    "model_parameters",
    "feature_selector",
    "selector_parameters",
    "scaler",
    "scaler_parameters",
    "feature_generator",
    "feature_generator_parameters",
]

# %%
import os
import os.path
import pickle
import pandas as pd
import functions
import seaborn as sns
import matplotlib.pyplot as plt

# %%
results = []
for directory in DIRECTORIES:
    for f in os.listdir(directory):
        if os.path.isfile(os.path.join(directory, f)):
            with open(os.path.join(directory, f), "rb") as input_file:
                results.append(pickle.load(input_file))

# %%
for i, result in enumerate(results):
    if len(result[0]) == 9:
        results[i] = pd.DataFrame(result, columns=OLD_COLUMNS)
        functions.addColumnsScalerGenerator(results[i])
    else:
        results[i] = pd.DataFrame(result, columns=NEW_COLUMNS)

# %%
allResults = pd.concat(results,ignore_index=True)

# %%
allResults.iloc[allResults["score"].idxmax()]
# Out:
# score                                                                    0.617737
# numberOfTruePositives                                                         242
# accuracy                                                                  0.56303
# precision                                                                0.572519
# numberOfFeatures                                                                2
# model                                                               MLPClassifier
# model_parameters                {'activation': 'relu', 'solver': 'adam', 'beta...
# feature_selector                                                            KBest
# selector_parameters             {'score_func': <function mutual_info_classif a...
# feature_generator_parameters                                                   {}
# feature_generator                                             NoFeatureGeneration
# scaler_parameters                                                              {}
# scaler                                                                     Robust
# Name: 34847, dtype: object

# %%
allResults
# Out:
#          score  numberOfTruePositives  accuracy  precision  numberOfFeatures  \
# 0   -15.818627                    319  0.500606   0.495192               500
# 1   -15.785948                    339  0.513333   0.506639               500
# 2   -15.808824                    325  0.509091   0.503555               500
# 3   -15.602941                    451  0.662424   0.660074               500
# 4   -15.620915                    440  0.657576   0.643757               500
# ..         ...                    ...       ...        ...               ...
# 895  -0.039755                    187  0.493939   0.494175                10
# 896  -0.039755                    187  0.493939   0.494175                10
# 897  -0.048930                    184  0.518788   0.512249                10
# 898  -0.048930                    184  0.518788   0.512249                10
# 899  -0.048930                    184  0.518788   0.512249                10
#
#                     model                                   model_parameters  \
# 0                     LDA                                  {'solver': 'svd'}
# 1                     QDA                                                 {}
# 2                     KNN                                 {'n_neighbors': 5}
# 3        GradientBoosting                                                 {}
# 4    HistGradientBoosting                                                 {}
# ..                    ...                                                ...
# 895               XGBoost  {'max_depth': 3, 'eta': 0.0001, 'objective': '...
# 896               XGBoost  {'max_depth': 3, 'eta': 0.0001, 'objective': '...
# 897               XGBoost  {'max_depth': 3, 'eta': 0.01, 'objective': 'bi...
# 898               XGBoost  {'max_depth': 3, 'eta': 0.01, 'objective': 'bi...
# 899               XGBoost  {'max_depth': 3, 'eta': 0.01, 'objective': 'bi...
#
#        feature_selector                                selector_parameters  \
# 0    NoFeatureSelection                                                 {}
# 1    NoFeatureSelection                                                 {}
# 2    NoFeatureSelection                                                 {}
# 3    NoFeatureSelection                                                 {}
# 4    NoFeatureSelection                                                 {}
# ..                  ...                                                ...
# 895                 RFE  {'estimator': SVC(kernel='linear'), 'n_feature...
# 896                 RFE  {'estimator': SVC(kernel='linear'), 'n_feature...
# 897                 RFE  {'estimator': SVC(kernel='linear'), 'n_feature...
# 898                 RFE  {'estimator': SVC(kernel='linear'), 'n_feature...
# 899                 RFE  {'estimator': SVC(kernel='linear'), 'n_feature...
#
#     feature_generator_parameters    feature_generator scaler_parameters  \
# 0                            NaN  NoFeatureGeneration               NaN
# 1                            NaN  NoFeatureGeneration               NaN
# 2                            NaN  NoFeatureGeneration               NaN
# 3                            NaN  NoFeatureGeneration               NaN
# 4                            NaN  NoFeatureGeneration               NaN
# ..                           ...                  ...               ...
# 895                {'degree': 2}           Polynomial                {}
# 896                {'degree': 2}           Polynomial                {}
# 897                {'degree': 2}           Polynomial                {}
# 898                {'degree': 2}           Polynomial                {}
# 899                {'degree': 2}           Polynomial                {}
#
#         scaler
# 0    NoScaling
# 1    NoScaling
# 2    NoScaling
# 3    NoScaling
# 4    NoScaling
# ..         ...
# 895     Robust
# 896     Robust
# 897     Robust
# 898     Robust
# 899     Robust
#
# [101261 rows x 13 columns]

# %% [markdown]
# ## All unique parameters
#
# Note that not all of these combinations were tested, but at some point each of these parameters was tested

# %%
params = functions.extractAllUniqueParameters(
    allResults,
    [
        "model",
        "feature_selector",
        "scaler",
        "feature_generator",
    ],
    [
        "model_parameters",
        "selector_parameters",
        "scaler_parameters",
        "feature_generator_parameters",
    ],
)

# %%
temp = {}
for paramKey in params.keys():
    if paramKey =='NoScaling' or paramKey =='NoFeatureGeneration':
        temp[paramKey] = {}
        continue
    if paramKey == "Voting":
        params["Voting"] = params["Voting"].explode("estimators")
    temp[paramKey] = {}
    for col in params[paramKey]:
        temp[paramKey][col] = params[paramKey][col].unique()

# %%
params["Voting"].explode("estimators")
# Out:
#                                            estimators voting
# 0                                                   1   soft
# 0   GradientBoostingClassifier(learning_rate=0.01,...   soft
# 0                                                   2   soft
# 0        MLPClassifier(max_iter=800, random_state=42)   soft
# 0                                                   3   soft
# ..                                                ...    ...
# 28  GradientBoostingClassifier(learning_rate=0.01,...   soft
# 28                                                  2   soft
# 28       MLPClassifier(max_iter=800, random_state=42)   soft
# 28                                                  3   soft
# 28                    QuadraticDiscriminantAnalysis()   soft
#
# [174 rows x 2 columns]

# %%
temp
# Out:
# {'ADABoost': {'estimator': array([GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                     n_estimators=800, random_state=42)     ,
#          GradientBoostingClassifier(learning_rate=0.001, loss='exponential',
#                                     n_estimators=800, random_state=42)      ,
#          DecisionTreeClassifier()], dtype=object),
#   'n_estimators': array([50], dtype=int64),
#   'learning_rate': array([1.  , 0.5 , 0.1 , 0.01]),
#   'random_state': array([42], dtype=int64)},
#  'GradientBoosting': {'loss': array([nan, 'exponential', 'log_loss'], dtype=object),
#   'learning_rate': array([  nan, 0.01 , 0.001, 0.1  ]),
#   'n_estimators': array([ nan, 100., 200., 300., 500., 800., 400.]),
#   'subsample': array([nan, 1. , 0.7]),
#   'max_depth': array([nan,  2.,  3.,  5.,  8.]),
#   'random_state': array([nan, 42.]),
#   'max_features': array([nan,  3.,  5.,  8.]),
#   'ccp_alpha': array([ nan, 0.  , 0.01, 0.05, 0.1 ]),
#   'min_samples_split': array([nan,  2.,  4., 10., 20.]),
#   'min_samples_leaf': array([nan,  1.,  2.,  5.,  7.]),
#   'min_impurity_decrease': array([nan,  0.,  1.,  5.])},
#  'HistGradientBoosting': {'learning_rate': array([ nan, 0.1 , 0.01]),
#   'max_depth': array([nan,  2.,  3.,  5.]),
#   'random_state': array([nan, 42.]),
#   'max_features': array([nan,  1.]),
#   'l2_regularization': array([nan, 0. , 0.5, 0.8])},
#  'KNN': {'n_neighbors': array([5, 3, 8], dtype=int64),
#   'weights': array([nan, 'uniform', 'distance'], dtype=object),
#   'p': array([nan,  1.,  2.]),
#   'leaf_size': array([nan, 15., 30., 50.])},
#  'LDA': {'solver': array(['svd', 'lsqr'], dtype=object),
#   'shrinkage': array([nan, None, 'auto'], dtype=object),
#   'n_components': array([nan])},
#  'MLPClassifier': {'activation': array([nan, 'identity', 'logistic', 'tanh', 'relu'], dtype=object),
#   'solver': array([nan, 'lbfgs', 'adam', 'sgd'], dtype=object),
#   'alpha': array([    nan, 1.0e-03, 1.0e-02, 1.0e-04, 1.0e-01, 5.0e-03, 2.0e-01,
#          1.5e-01, 5.0e-02, 3.0e-01, 4.0e-01]),
#   'learning_rate': array([nan, 'constant', 'adaptive', 'invscaling'], dtype=object),
#   'learning_rate_init': array([   nan, 0.001 , 0.0001, 0.01  , 0.005 , 0.002 , 0.003 , 0.004 ,
#          0.009 , 0.008 , 0.007 , 0.006 ]),
#   'max_iter': array([  nan, 1600.,  800.]),
#   'random_state': array([nan, 42.]),
#   'hidden_layer_sizes': array([nan, (100,), (200,), (400,), (50,), (20,), (10,), (30,), (11,),
#          (12,), (13,), (14,), (15,), (16,), (17,), (81,), (19,), (21,),
#          (22,), (23,), (24,), (25,), (26,), (27,), (28,), (29,), (300,)],
#         dtype=object),
#   'beta_1': array([ nan, 0.9 , 0.95, 0.85]),
#   'beta_2': array([  nan, 0.999, 0.9  , 0.95 ])},
#  'QDA': {'reg_param': array([nan, 0. , 0.3, 0.5, 0.8])},
#  'Voting': {'estimators': array([('1', GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                     n_estimators=200, random_state=42))          ,
#          ('2', MLPClassifier(max_iter=800, random_state=42)),
#          ('3', QuadraticDiscriminantAnalysis()),
#          ('1', GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                     n_estimators=200, random_state=42))          ,
#          ('2', MLPClassifier(max_iter=800, random_state=42)),
#          ('3', QuadraticDiscriminantAnalysis()),
#          ('1', GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                     n_estimators=200, random_state=42))          ,
#          ('2', MLPClassifier(max_iter=800, random_state=42)),
#          ('3', QuadraticDiscriminantAnalysis()),
#          ('1', GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                     n_estimators=200, random_state=42))          ,
#          ('2', MLPClassifier(max_iter=800, random_state=42)),
#          ('3', QuadraticDiscriminantAnalysis())], dtype=object),
#   'voting': array(['soft'], dtype=object)},
#  'XGBoost': {'max_depth': array([2, 3], dtype=int64),
#   'eta': array([0.001 , 0.0001, 0.01  ]),
#   'objective': array(['binary:logistic'], dtype=object),
#   'nthread': array([4, 2, 8], dtype=int64),
#   'eval_metric': array(['auc'], dtype=object)},
#  'FDR': {'score_func': array([<function f_classif at 0x0000024AFFCEEB60>], dtype=object),
#   'alpha': array([0.8])},
#  'FPR': {'score_func': array([<function f_classif at 0x0000024AFFCEEB60>], dtype=object),
#   'alpha': array([0.01, 0.05, 0.1 , 0.2 ])},
#  'KBest': {'score_func': array([<function f_classif at 0x0000024AFFCEEB60>,
#          <function mutual_info_classif at 0x0000024AFFCECEA0>], dtype=object),
#   'k': array([ 5, 10, 20, 40, 80,  2,  3,  4,  6,  7,  8,  9], dtype=int64)},
#  'NoFeatureSelection': {},
#  'PCA': {'n_components': array([2, 3], dtype=int64),
#   'random_state': array([42], dtype=int64)},
#  'RFE': {'estimator': array([SVC(kernel='linear'), SVC(kernel='linear'), SVC(kernel='linear'),
#          SVC(kernel='linear'), SVC(kernel='linear'), SVC(kernel='linear'),
#          SVC(kernel='linear')], dtype=object),
#   'n_features_to_select': array([ 2,  3,  5, 10, 20], dtype=int64),
#   'step': array([0.9])},
#  'RFECV': {'estimator': array([SVC(kernel='linear')], dtype=object),
#   'min_features_to_select': array([ 5, 10, 20], dtype=int64),
#   'step': array([0.9]),
#   'cv': array([5], dtype=int64)},
#  'NoScaling': {},
#  'Robust': {},
#  'Standard': {},
#  'NoFeatureGeneration': {},
#  'Polynomial': {'degree': array([2, 3], dtype=int64)}}

# %% [markdown]
# ## Results summary
#
# The results need to be represented somehow, mayeb outliers could be removed to make the graphs better looking?

# %%
sns.boxplot(data=allResults, x="model", y="score")
# Out:
# <Axes: xlabel='model', ylabel='score'>
